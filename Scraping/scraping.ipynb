# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Source Investigation
# - https://fbref.com/en/ recently banned web scraping and the use of it's data,
# - https://www.football-data.co.uk/englandm.php has many CSV files showing the results and some stats for each game,
# - https://understat.com/league/EPL contains XG for all games in the premier league for the last 10 years.
#
# I have chosen to combine the latter 2:
